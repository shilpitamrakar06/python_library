# %%
import pandas as pd 
import numpy as np

# %%
## for even columns: 

df1 = pd.DataFrame({'A':[1,2,3,4],'B':[5,6,7,8]}) 
df2 = pd.DataFrame({"C":[10,20,30,40],"D":[50,60,70,80]}) 
print(df1) 
print(df2)
# Out:
#    A  B
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8
#     C   D
# 0  10  50
# 1  20  60
# 2  30  70
# 3  40  80

# %%
df1.join (df2) ## join two table
# Out:
#    A  B   C   D
# 0  1  5  10  50
# 1  2  6  20  60
# 2  3  7  30  70
# 3  4  8  40  80

# %%
# for uneven columns : it fills nan 

df1 = pd.DataFrame({'A':[1,2,3,4],'B':[5,6,7,8]}) 
df2 = pd.DataFrame({"C":[10,20],"D":[50,60]}) 
df1.join (df2)
# Out:
#    A  B     C     D
# 0  1  5  10.0  50.0
# 1  2  6  20.0  60.0
# 2  3  7   NaN   NaN
# 3  4  8   NaN   NaN

# %%
# for uneven columns: assigning index for uneven columns : it wont disply  the ddata of less 
df1 = pd.DataFrame({'A':[1,2,3,4],'B':[5,6,7,8]},index=['a','b','c','d']) 
df2 = pd.DataFrame({"C":[10,20],"D":[50,60]}) 
df1.join(df2) ## priority with left dataframe
# Out:
#    A  B   C   D
# a  1  5 NaN NaN
# b  2  6 NaN NaN
# c  3  7 NaN NaN
# d  4  8 NaN NaN

# %%
df1 = pd.DataFrame({'A':[1,2,3,4],'B':[5,6,7,8]},index=['a','b','c','d']) 
df2 = pd.DataFrame({"C":[10,20],"D":[50,60]},index= ['c','d'])  
df1.join(df2)
# Out:
#    A  B     C     D
# a  1  5   NaN   NaN
# b  2  6   NaN   NaN
# c  3  7  10.0  50.0
# d  4  8  20.0  60.0

# %%
df1 = pd.DataFrame({'A':[1,2,3,4],'B':[5,6,7,8]}) 
df2 = pd.DataFrame({"C":[10,20,30,40],"D":[50,60,70,80]},index= ['a','b','c','d'])   
df2.join(df1)
# Out:
#     C   D   A   B
# a  10  50 NaN NaN
# b  20  60 NaN NaN
# c  30  70 NaN NaN
# d  40  80 NaN NaN

# %%
df3 = pd.DataFrame({'A':[1,2,3,4],'B':[5,6,7,8]},index=['a','b','c','d']) 
df4 = pd.DataFrame({"C":[10,20,30,40],"D":[50,60,70,80]},index= ['a','b','x','d'])   
df1.join(df2)  
print("inner join",df3.join(df4,how="inner")) 
print("left join",df3.join(df4,how="left"))
print("right join",df3.join(df4,how="right"))
# Out:
# inner join    A  B   C   D
# a  1  5  10  50
# b  2  6  20  60
# d  4  8  40  80
# left join    A  B     C     D
# a  1  5  10.0  50.0
# b  2  6  20.0  60.0
# c  3  7   NaN   NaN
# d  4  8  40.0  80.0
# right join      A    B   C   D
# a  1.0  5.0  10  50
# b  2.0  6.0  20  60
# x  NaN  NaN  30  70
# d  4.0  8.0  40  80

# %%
df3 = pd.DataFrame({'A':[1,2,3,4],'B':[5,6,7,8]},index=['a','b','c','d']) 
df4 = pd.DataFrame({"B":[10,20,30,40],"D":[50,60,70,80]},index= ['a','b','c','d'])   ## join index wise work krta    
df3.join(df4,how="left",lsuffix="L",rsuffix="R")
# Out:
#    A  BL  BR   D
# a  1   5  10  50
# b  2   6  20  60
# c  3   7  30  70
# d  4   8  40  80

# %%
d1 = pd.DataFrame([100,200,300,400]) 
d2 = pd.DataFrame([400,500,600,700]) 
d3 = pd.concat([d1,d2]) 
print("concat",d3)
# Out:
# concat      0
# 0  100
# 1  200
# 2  300
# 3  400
# 0  400
# 1  500
# 2  600
# 3  700

# %%
## concat 
df3 = pd.DataFrame({'A':[1,2,3,4],'B':[5,6,7,8]},index=['a','b','c','d']) 
df4 = pd.DataFrame({"B":[10,20,30,40],"D":[50,60,70,80]},index= ['a','b','c','d'])   
df5 = pd.concat([df3,df4],ignore_index=True) # rowwise : it repeat indexing 
print(df5)
# Out:
#      A   B     D
# 0  1.0   5   NaN
# 1  2.0   6   NaN
# 2  3.0   7   NaN
# 3  4.0   8   NaN
# 4  NaN  10  50.0
# 5  NaN  20  60.0
# 6  NaN  30  70.0
# 7  NaN  40  80.0

# %%
j1 = pd.DataFrame({"A":[1,2,3,4],"B":[5,6,7,8]}) 
j1 
j2 =pd.DataFrame({"B":[10,20,30,40],"C":[50,60,70,80]}) 
j2
# Out:
#     B   C
# 0  10  50
# 1  20  60
# 2  30  70
# 3  40  80

# %%
print(j1.merge(j2))  ## by default how inner leta hai
# Out:
# Empty DataFrame
# Columns: [A, B, C]
# Index: []

# %%
j1 = pd.DataFrame({"A":[1,2,3,4],"B":[5,6,7,8]}) 
j1 
j2 =pd.DataFrame({"B":[1,20,5,7],"C":[50,60,70,80]})   ## values same hone pr output  deta hai 
j2 
print(j1.merge(j2))
# Out:
#    A  B   C
# 0  1  5  70
# 1  3  7  80

# %%
j1 = pd.DataFrame({"A":[1,2,3,4],"B":[5,6,7,8]}) 
j1 
j2 =pd.DataFrame({"B":[1,20,5,7],"C":[50,60,70,80]})   ## values same hone pr output  deta hai 
j2
# Out:
#     B   C
# 0   1  50
# 1  20  60
# 2   5  70
# 3   7  80

# %%
j1 = pd.DataFrame({"A":[1,2,3,4],"B":[5,6,7,8]}) 
print(j1) 
j2 =pd.DataFrame({"B":[10,5,30,7],"C":[50,60,70,80]}) 
print(j2) 
j1.merge(j2,on="B",how="left")
# Out:
#    A  B
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8
#     B   C
# 0  10  50
# 1   5  60
# 2  30  70
# 3   7  80
#    A  B     C
# 0  1  5  60.0
# 1  2  6   NaN
# 2  3  7  80.0
# 3  4  8   NaN

# %%
j1 = pd.DataFrame({"A":[1,2,3,4],"B":[5,6,7,8]}) 
print(j1) 
j2 =pd.DataFrame({"B":[10,5,30,7],"C":[50,60,70,80]}) 
print(j2) 
j1.merge(j2,on="B",how="right")
# Out:
#    A  B
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8
#     B   C
# 0  10  50
# 1   5  60
# 2  30  70
# 3   7  80
#      A   B   C
# 0  NaN  10  50
# 1  1.0   5  60
# 2  NaN  30  70
# 3  3.0   7  80
