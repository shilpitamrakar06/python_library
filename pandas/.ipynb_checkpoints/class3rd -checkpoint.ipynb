# %%
import pandas as pd 
import numpy as np

# %%
## describe function = five number function (five values ) 
a = [10,20,30,40,50,60,70,80] 
s = pd.Series(a) 
print(s)
print(s.describe())
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# 6    70
# 7    80
# dtype: int64
# count     8.000000
# mean     45.000000
# std      24.494897
# min      10.000000
# 25%      27.500000
# 50%      45.000000
# 75%      62.500000
# max      80.000000
# dtype: float64
