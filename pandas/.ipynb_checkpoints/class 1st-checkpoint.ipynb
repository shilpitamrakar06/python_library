# %%
import pandas as pd 
import numpy as np

# %%
a = [1,2,3,4,5] 
print(a)
print(type(a))
k = pd.Series(a) 
print(k) 
print(type(k))
# Out:
# [1, 2, 3, 4, 5]
# <class 'list'>
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.Series'>
