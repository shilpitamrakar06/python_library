# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('Customer Churn.csv') 
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# 1             Yes                No             DSL            Yes  ...
# 2             Yes                No             DSL            Yes  ...
# 3              No  No phone service             DSL            Yes  ...
# 4             Yes                No     Fiber optic             No  ...
# ...           ...               ...             ...            ...  ...
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0                  No          No          No              No  Month-to-month
# 1                 Yes          No          No              No        One year
# 2                  No          No          No              No  Month-to-month
# 3                 Yes         Yes          No              No        One year
# 4                  No          No          No              No  Month-to-month
# ...               ...         ...         ...             ...             ...
# 7038              Yes         Yes         Yes             Yes        One year
# 7039              Yes          No         Yes             Yes        One year
# 7040               No          No          No              No  Month-to-month
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 0                 Yes           Electronic check          29.85         29.85
# 1                  No               Mailed check          56.95        1889.5
# 2                 Yes               Mailed check          53.85        108.15
# 3                  No  Bank transfer (automatic)          42.30       1840.75
# 4                 Yes           Electronic check          70.70        151.65
# ...               ...                        ...            ...           ...
# 7038              Yes               Mailed check          84.80        1990.5
# 7039              Yes    Credit card (automatic)         103.20        7362.9
# 7040              Yes           Electronic check          29.60        346.45
# 7041              Yes               Mailed check          74.40         306.6
# 7042              Yes  Bank transfer (automatic)         105.65        6844.5
#
#      Churn
# 0       No
# 1       No
# 2      Yes
# 3       No
# 4      Yes
# ...    ...
# 7038    No
# 7039    No
# 7040    No
# 7041   Yes
# 7042    No
#
# [7043 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
#  17  PaymentMethod     7043 non-null   str
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   str
#  20  Churn             7043 non-null   str
# dtypes: float64(1), int64(2), str(18)
# memory usage: 1.1 MB

# %%
df.columns = df.columns.str.lower()
df.columns
# Out:
# Index(['customerid', 'gender', 'seniorcitizen', 'partner', 'dependents',
#        'tenure', 'phoneservice', 'multiplelines', 'internetservice',
#        'onlinesecurity', 'onlinebackup', 'deviceprotection', 'techsupport',
#        'streamingtv', 'streamingmovies', 'contract', 'paperlessbilling',
#        'paymentmethod', 'monthlycharges', 'totalcharges', 'churn'],
#       dtype='str')

# %%
df.head()
# Out:
#    customerid  gender  seniorcitizen partner dependents  tenure phoneservice  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       multiplelines internetservice onlinesecurity  ... deviceprotection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   techsupport streamingtv streamingmovies        contract paperlessbilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                paymentmethod monthlycharges  totalcharges churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
df.isnull().sum()
# Out:
# customerid          0
# gender              0
# seniorcitizen       0
# partner             0
# dependents          0
# tenure              0
# phoneservice        0
# multiplelines       0
# internetservice     0
# onlinesecurity      0
# onlinebackup        0
# deviceprotection    0
# techsupport         0
# streamingtv         0
# streamingmovies     0
# contract            0
# paperlessbilling    0
# paymentmethod       0
# monthlycharges      0
# totalcharges        0
# churn               0
# dtype: int64

# %%
df['totalcharges'] = df['totalcharges'].replace(" ","0")
df['totalcharges'] = df['totalcharges'].astype("float")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerid        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   seniorcitizen     7043 non-null   int64
#  3   partner           7043 non-null   str
#  4   dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   phoneservice      7043 non-null   str
#  7   multiplelines     7043 non-null   str
#  8   internetservice   7043 non-null   str
#  9   onlinesecurity    7043 non-null   str
#  10  onlinebackup      7043 non-null   str
#  11  deviceprotection  7043 non-null   str
#  12  techsupport       7043 non-null   str
#  13  streamingtv       7043 non-null   str
#  14  streamingmovies   7043 non-null   str
#  15  contract          7043 non-null   str
#  16  paperlessbilling  7043 non-null   str
#  17  paymentmethod     7043 non-null   str
#  18  monthlycharges    7043 non-null   float64
#  19  totalcharges      7043 non-null   float64
#  20  churn             7043 non-null   str
# dtypes: float64(2), int64(2), str(17)
# memory usage: 1.1 MB

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        seniorcitizen       tenure  monthlycharges  totalcharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2279.734304
# std         0.368612    24.559481       30.090047   2266.794470
# min         0.000000     0.000000       18.250000      0.000000
# 25%         0.000000     9.000000       35.500000    398.550000
# 50%         0.000000    29.000000       70.350000   1394.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['customerid'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df['seniorcitizen'] = df['seniorcitizen'].replace({0:"no",1:"yes"})

# %%
df.sample(40)
# Out:
#       customerid  gender seniorcitizen partner dependents  tenure  \
# 6956  2451-YMUXS    Male           yes      No         No      67
# 1782  8623-ULFNQ  Female           yes      No         No      26
# 3917  3871-IKPYH    Male           yes      No         No       1
# 2033  8305-VHZBZ    Male            no      No         No       1
# 4440  3397-AVTKU    Male            no      No         No      43
# 2457  5198-EFNBM    Male           yes     Yes         No      57
# 5302  9700-ISPUP  Female            no     Yes        Yes      10
# 4749  6633-MPWBS    Male            no      No         No       5
# 6825  5022-KVDQT    Male            no      No         No      27
# 4008  0743-HRVFF  Female            no     Yes        Yes      51
# 1141  1641-BYBTK    Male            no      No        Yes       6
# 2927  5542-TBBWB    Male            no      No         No       1
# 3036  4702-HDRKD    Male            no      No         No      67
# 4735  0723-FDLAY    Male            no      No         No      44
# 5012  9367-TCUYN  Female            no      No         No      12
# 2121  0673-IGUQO    Male            no      No         No       1
# 5600  3799-ISUZQ    Male            no     Yes        Yes       7
# 703   6942-LBFDP  Female            no      No         No       2
# 3789  0310-VQXAM    Male            no      No         No       9
# 4202  3146-JTQHR    Male            no     Yes         No      10
# 3194  6397-JNZZG  Female           yes     Yes         No      43
# 359   9833-TGFHX    Male            no     Yes        Yes      42
# 4608  0813-TAXXS    Male            no      No         No      55
# 3114  0867-LDTTC    Male            no      No         No       5
# 2883  7225-IILWY    Male            no     Yes        Yes      68
# 3748  6339-RZCBJ    Male            no      No         No      48
# 2119  9805-FILKB    Male            no     Yes        Yes      46
# 4722  7581-EBBOU  Female            no      No         No      60
# 6156  0118-JPNOY  Female           yes      No         No      26
# 6913  8213-TAZPM  Female            no     Yes        Yes      69
# 6682  9589-ABEPT    Male            no     Yes         No      69
# 5208  6502-KUGLL  Female            no     Yes        Yes      14
# 1834  8080-DDEMJ    Male           yes      No         No       1
# 4999  1699-TLDLZ  Female            no     Yes        Yes      16
# 2296  4706-DGAHW    Male           yes      No         No       1
# 5611  6847-KJLTS  Female           yes     Yes         No      58
# 1747  3198-VELRD  Female            no     Yes        Yes       3
# 5446  6141-OOXUQ    Male            no      No         No       1
# 6330  9921-QFQUL  Female            no     Yes         No      23
# 6113  1228-ZLNBX    Male            no      No         No      21
#
#      phoneservice     multiplelines internetservice       onlinesecurity  ...  \
# 6956          Yes               Yes             DSL                  Yes  ...
# 1782          Yes               Yes             DSL                   No  ...
# 3917          Yes                No     Fiber optic                   No  ...
# 2033          Yes                No              No  No internet service  ...
# 4440          Yes                No             DSL                   No  ...
# 2457          Yes                No     Fiber optic                   No  ...
# 5302          Yes                No             DSL                   No  ...
# 4749          Yes                No             DSL                   No  ...
# 6825          Yes               Yes     Fiber optic                   No  ...
# 4008           No  No phone service             DSL                   No  ...
# 1141          Yes                No              No  No internet service  ...
# 2927          Yes                No     Fiber optic                   No  ...
# 3036           No  No phone service             DSL                  Yes  ...
# 4735          Yes               Yes             DSL                   No  ...
# 5012          Yes                No              No  No internet service  ...
# 2121          Yes                No              No  No internet service  ...
# 5600          Yes                No     Fiber optic                   No  ...
# 703           Yes                No              No  No internet service  ...
# 3789          Yes                No              No  No internet service  ...
# 4202          Yes                No              No  No internet service  ...
# 3194           No  No phone service             DSL                   No  ...
# 359           Yes               Yes     Fiber optic                  Yes  ...
# 4608          Yes               Yes             DSL                   No  ...
# 3114          Yes                No             DSL                   No  ...
# 2883          Yes               Yes              No  No internet service  ...
# 3748          Yes                No             DSL                   No  ...
# 2119          Yes                No              No  No internet service  ...
# 4722          Yes                No             DSL                   No  ...
# 6156          Yes                No     Fiber optic                  Yes  ...
# 6913          Yes               Yes     Fiber optic                   No  ...
# 6682          Yes               Yes     Fiber optic                   No  ...
# 5208          Yes                No             DSL                  Yes  ...
# 1834                   No  Month-to-month               No
# 4999  No internet service        Two year               No
# 2296                   No  Month-to-month               No
# 5611                  Yes  Month-to-month              Yes
# 1747                  Yes  Month-to-month              Yes
# 5446  No internet service  Month-to-month               No
# 6330                  Yes  Month-to-month               No
# 6113                   No  Month-to-month               No
#
#                   paymentmethod monthlycharges  totalcharges  churn
# 6956  Bank transfer (automatic)          64.55       4250.10     No
# 1782           Electronic check          66.05       1652.40     No
# 3917           Electronic check          69.10         69.10    Yes
# 2033               Mailed check          20.20         20.20    Yes
# 4440           Electronic check          60.00       2548.55     No
# 2457           Electronic check          90.65       5199.80     No
# 5302           Electronic check          65.50        616.90     No
# 4749           Electronic check          49.20        216.90    Yes
# 6825           Electronic check          81.30       2272.80     No
# 4008           Electronic check          56.15       2898.95     No
# 1141               Mailed check          20.20         98.35     No
# 2927           Electronic check          69.90         69.90     No
# 3036  Bank transfer (automatic)          49.35       3321.35     No
# 4735  Bank transfer (automatic)          85.25       3704.15     No
# 5012               Mailed check          20.10        223.60     No
# 2121               Mailed check          20.45         20.45     No
# 5600  Bank transfer (automatic)          69.95        529.50    Yes
# 703                Mailed check          20.55         33.60     No
# 3789               Mailed check          19.85        178.80     No
# 4202  Bank transfer (automatic)          19.60        189.45     No
# 3194    Credit card (automatic)          55.55       2342.20    Yes
# 359            Electronic check          97.10       4016.75     No
# 4608  Bank transfer (automatic)          77.80       4323.35     No
# 3114  Bank transfer (automatic)          75.15        392.65     No
# 2883               Mailed check          25.75       1686.15     No
# 3748    Credit card (automatic)          78.90       3771.50     No
# 2119  Bank transfer (automatic)          20.20        845.60     No
# 4722    Credit card (automatic)          70.15       4224.70     No
# 6156    Credit card (automatic)          85.80       2193.65     No
# 6913  Bank transfer (automatic)         108.75       7493.05     No
# 6682               Mailed check          92.45       6460.55     No
# 5208  Bank transfer (automatic)          59.45        780.85     No
# 1834           Electronic check          45.10         45.10    Yes
# 4999               Mailed check          19.70        301.55     No
# 2296           Electronic check          45.20         45.20     No
# 5611  Bank transfer (automatic)         100.40       5749.80     No
# 1747  Bank transfer (automatic)          84.75        264.85    Yes
# 5446               Mailed check          19.65         19.65    Yes
# 6330               Mailed check          90.15       2044.95     No
# 6113               Mailed check          75.30       1570.70     No
#
# [40 rows x 21 columns]

# %%
ax=sns.countplot(x='churn',data=df)
ax.bar_label(ax.containers[0])
plt.show()

# %%
plt.figure(figsize=(4,5))
gb = df.groupby('churn').agg({"churn":'count'}) 
e= [0.1,0]
plt.pie(gb['churn'],labels=gb.index ,autopct="%1.2f%%",explode=e,shadow=True)
plt.title("percentage of churn customers")
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.countplot(x="gender", data=df, hue="churn") 
plt.title("churn by gender")
plt.show()

# %%
plt.figure(figsize=(4,4))
ax = sns.countplot(x="seniorcitizen", data=df) 
ax.bar_label(ax.containers[0])
plt.title("churn by seniorcitizen")
plt.show()

# %%
##   comparative a greater number of people in sseniorcitizen category have churned
