# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
## matrix plot 
#heatmap :: use  for numerical column 
#cluster

# %%
## heatmap 
dt = sns.load_dataset("tips")
dt.head() 
dt.columns
t = dt[["total_bill","tip","size"]].head(10)
t
sns.heatmap(t.corr(),annot=True) ## corr :: for relation
# Out:
# <Axes: >

# %%
##cluster map  
pt =sns.load_dataset("iris") 
pt
sns.clustermap(pt.iloc[:,[0,1,2,3]]) 
plt.show()

# %%
dt = sns.load_dataset("tips")
#categorical distribution plot (boxplot and violin in plot ) 
sns.boxplot (data=dt,x="day",y="total_bill")
#sns.violinplot(data=dt,x="day",y="total_bill",hue="sex",split=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(data=dt,x="day",y="total_bill",hue="sex",split=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>
